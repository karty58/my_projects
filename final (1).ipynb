# %% [markdown]
# **INTRODUCTION**:
#
# Human Immunodeficiency Virus (HIV) is a viral infection that attacks the immune system, potentially progressing to Acquired Immunodeficiency Syndrome (AIDS) if left untreated. With no known cure, individuals carry the virus for life, but advancements in medical care, particularly Antiretroviral Therapy (ART), can effectively manage HIV and control its progression. HIV symptoms vary but may include flu-like manifestations and persistent fatigue. As a retrovirus, HIV integrates into the host's DNA, presenting challenges for treatment. AIDS is the advanced stage of HIV, marked by severe immune system compromise and susceptibility to opportunistic infections. While AIDS itself is not transmissible, the HIV virus can be transmitted through various means, emphasizing the importance of preventive measures. This brief overview underscores the significance of timely medical intervention and public health efforts in addressing the impact of HIV/AIDS.

# %% [markdown]
# **Data Sources**
#
# https://www.kaggle.com/datasets/programmerrdai/hiv-aids - tb patient living with hiv receiving art as json downloaded from Kaggle
#
#
# https://www.kaggle.com/datasets/programmerrdai/hiv-aids - tb patients tested positive for hiv as csv downloaded from kaggle
#
#
#
# https://www.kaggle.com/datasets/programmerrdai/hiv-aids  - tb related deaths hiv.xls as excel downloaded from kaggle
#
#
# datasets saved in google drive:
# https://drive.google.com/drive/folders/1rE-G8V3fVflpyRMVR3-HmsdI0jMwBEzJ?usp=drive_link

# %% [markdown]
# **Loading the data**

# %%
import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **DATA 1**
#
# The dataset presents information on the incidence of individuals testing positive for both Tuberculosis (TB) and Human Immunodeficiency Virus (HIV) in various countries from 2007 to 2016. It includes details such as the country's name, country code, the specific year of observation, and the total count of TB patients who tested positive for HIV in each corresponding year. This dataset serves to quantify and highlight the prevalence of co-infection between TB and HIV across different nations, offering valuable insights into trends and patterns over the specified timeframe, and aiding in the formulation of targeted public health strategies.

# %%
data1 = pd.read_csv("tb-patients-tested-positive-for-hiv.csv")
# display original
data1
# Out:
#            Entity Code  Year  TB patients tested positive for HIV - Total
# 0     Afghanistan  AFG  2007                                            0
# 1     Afghanistan  AFG  2008                                            0
# 2     Afghanistan  AFG  2009                                            5
# 3     Afghanistan  AFG  2010                                            2
# 4     Afghanistan  AFG  2011                                            5
# ...           ...  ...   ...                                          ...
# 2364     Zimbabwe  ZWE  2012                                        25508
# 2365     Zimbabwe  ZWE  2013                                        23075
# 2366     Zimbabwe  ZWE  2014                                        19290
# 2367     Zimbabwe  ZWE  2015                                        18072
# 2368     Zimbabwe  ZWE  2016                                        18327
#
# [2369 rows x 4 columns]

# %% [markdown]
# **Renaming the columns**

# %%
# Rename the column 'TB patients tested positive for HIV - Total' to 'tb_positive_count' in the 'data1' DataFrame
data1 = data1.rename(columns={'TB patients tested positive for HIV - Total': 'tb_positive_count'})
data1# Rename the column 'TB patients tested positive for HIV - Total' to 'tb_positive_count' in the 'data1' DataFrame
def rename_column(dataframe, old_column, new_column):
    """
    Rename a column in a DataFrame.
    (pd.DataFrame, str, str)->str
    """
    dataframe = dataframe.rename(columns={old_column: new_column})
    return dataframe

# Rename the column 'TB patients tested positive for HIV - Total' to 'tb_positive_count'
data1 = rename_column(data1, 'TB patients tested positive for HIV - Total', 'tb_positive_count')
data1
# Out:
#            Entity Code  Year  tb_positive_count
# 0     Afghanistan  AFG  2007                  0
# 1     Afghanistan  AFG  2008                  0
# 2     Afghanistan  AFG  2009                  5
# 3     Afghanistan  AFG  2010                  2
# 4     Afghanistan  AFG  2011                  5
# ...           ...  ...   ...                ...
# 2364     Zimbabwe  ZWE  2012              25508
# 2365     Zimbabwe  ZWE  2013              23075
# 2366     Zimbabwe  ZWE  2014              19290
# 2367     Zimbabwe  ZWE  2015              18072
# 2368     Zimbabwe  ZWE  2016              18327
#
# [2369 rows x 4 columns]

# %% [markdown]
# **Filtering the rows**

# %%
# Filter rows where 'Entity' is 'United States'
data_1 = data1[data1['Entity'] == 'United States']
# display original
data_1
# Out:
#              Entity Code  Year  tb_positive_count
# 2244  United States  USA  2003               1317
# 2245  United States  USA  2004               1188
# 2246  United States  USA  2005               1035
# 2247  United States  USA  2006                960
# 2248  United States  USA  2007                883
# 2249  United States  USA  2008                826
# 2250  United States  USA  2009                711
# 2251  United States  USA  2010                627
# 2252  United States  USA  2011                668
# 2253  United States  USA  2012                626
# 2254  United States  USA  2013                552
# 2255  United States  USA  2014                504
# 2256  United States  USA  2015                465
# 2257  United States  USA  2016                466

# %% [markdown]
# **DATA 2**
#
# This dataset offers estimates of Tuberculosis (TB)-related deaths among individuals living with Human Immunodeficiency Virus (HIV) in the United States throughout the period from 2000 to 2016. Specifically focusing on the United States, the dataset includes information such as the country's name (Entity), country code (Code), the respective year of observation, and the estimated number of TB-related deaths among people living with HIV for each year. This dataset provides valuable insights into the dynamics of TB-related mortality within the HIV-positive population over time, serving as a resource for understanding trends and patterns. The information is instrumental in informing public health strategies and interventions targeted at mitigating the impact of TB among individuals living with HIV in the United States.

# %%
data2 = pd.read_excel("tb-related-deaths-hiv.xls")
# display original
data2
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2000
# 1     Afghanistan  AFG  2001
# 2     Afghanistan  AFG  2002
# 3     Afghanistan  AFG  2003
# 4     Afghanistan  AFG  2004
# ...           ...  ...   ...
# 3773     Zimbabwe  ZWE  2012
# 3774     Zimbabwe  ZWE  2013
# 3775     Zimbabwe  ZWE  2014
# 3776     Zimbabwe  ZWE  2015
# 3777     Zimbabwe  ZWE  2016
#
#       Estimated TB-related deaths among people living with HIV - estimate
# 0                                               87.0184
# 1                                               74.7313
# 2                                               67.5944
# 3                                               69.5065
# 4                                               65.7143
# ...                                                 ...
# 3773                                         11538.7000
# 3774                                          8658.3000
# 3775                                          8511.3600
# ...

# %% [markdown]
# **Filtering rows**

# %%
# Filter rows in the 'data2' DataFrame where 'Entity' is 'United States'
data2 = data2[data2['Entity'] == 'United States']
data2
# Out:
#              Entity Code  Year  \
# 3574  United States  USA  2000
# 3575  United States  USA  2001
# 3576  United States  USA  2002
# 3577  United States  USA  2003
# 3578  United States  USA  2004
# 3579  United States  USA  2005
# 3580  United States  USA  2006
# 3581  United States  USA  2007
# 3582  United States  USA  2008
# 3583  United States  USA  2009
# 3584  United States  USA  2010
# 3585  United States  USA  2011
# 3586  United States  USA  2012
# 3587  United States  USA  2013
# 3588  United States  USA  2014
# 3589  United States  USA  2015
# 3590  United States  USA  2016
#
#       Estimated TB-related deaths among people living with HIV - estimate
# 3574                                           459.2060
# 3575                                           448.9290
# 3576                                           423.9000
# 3577                                           417.7620
# 3578                                           364.7660
# ...

# %% [markdown]
# **Renaming the Columns**

# %%
def rename_column(dataframe, old_column, new_column):
    """
    Rename a column in a DataFrame.
    (pd.DataFrame, int, int)-> int
    """
    dataframe = dataframe.rename(columns={old_column: new_column})
    return dataframe
# Rename the column 'Estimated TB-related deaths among people living with HIV - estimate' to 'TB_death_counts'
data2 = rename_column(data2, 'Estimated TB-related deaths among people living with HIV - estimate', 'TB_death_counts')

# Display the modified DataFrame
data2
# Out:
#              Entity Code  Year  TB_death_counts
# 3574  United States  USA  2000         459.2060
# 3575  United States  USA  2001         448.9290
# 3576  United States  USA  2002         423.9000
# 3577  United States  USA  2003         417.7620
# 3578  United States  USA  2004         364.7660
# 3579  United States  USA  2005         320.1740
# 3580  United States  USA  2006         285.9870
# 3581  United States  USA  2007         255.9080
# 3582  United States  USA  2008         231.4140
# 3583  United States  USA  2009         191.5700
# 3584  United States  USA  2010         170.3310
# 3585  United States  USA  2011         146.6090
# 3586  United States  USA  2012         126.3020
# 3587  United States  USA  2013         106.1010
# 3588  United States  USA  2014          97.0324
# 3589  United States  USA  2015          92.5329
# 3590  United States  USA  2016          85.9345

# %% [markdown]
# **Filtering the Rows**

# %%
def filter_data_by_year(dataframe, start_year, end_year):
    """
    Filter rows in a DataFrame based on a specified range of years.
    (pd.DataFrame, int, int)-> int
    """
    filtered_data = dataframe[(dataframe['Year'] >= start_year) & (dataframe['Year'] <= end_year)]
    return filtered_data

# Filter rows in data2 for the years 2003 to 2016
data2 = filter_data_by_year(data2, 2003, 2016)

# Display the filtered DataFrame
data2
# Out:
#              Entity Code  Year  TB_death_counts
# 3577  United States  USA  2003         417.7620
# 3578  United States  USA  2004         364.7660
# 3579  United States  USA  2005         320.1740
# 3580  United States  USA  2006         285.9870
# 3581  United States  USA  2007         255.9080
# 3582  United States  USA  2008         231.4140
# 3583  United States  USA  2009         191.5700
# 3584  United States  USA  2010         170.3310
# 3585  United States  USA  2011         146.6090
# 3586  United States  USA  2012         126.3020
# 3587  United States  USA  2013         106.1010
# 3588  United States  USA  2014          97.0324
# 3589  United States  USA  2015          92.5329
# 3590  United States  USA  2016          85.9345

# %% [markdown]
# **Merging the Data**

# %%
#merging the data_1 and data_2
merged_data = pd.merge(data_1, data2, on=['Entity', 'Code', 'Year'], how='inner')

# %%
merged_data
# Out:
#            Entity Code  Year  tb_positive_count  TB_death_counts
# 0   United States  USA  2003               1317         417.7620
# 1   United States  USA  2004               1188         364.7660
# 2   United States  USA  2005               1035         320.1740
# 3   United States  USA  2006                960         285.9870
# 4   United States  USA  2007                883         255.9080
# 5   United States  USA  2008                826         231.4140
# 6   United States  USA  2009                711         191.5700
# 7   United States  USA  2010                627         170.3310
# 8   United States  USA  2011                668         146.6090
# 9   United States  USA  2012                626         126.3020
# 10  United States  USA  2013                552         106.1010
# 11  United States  USA  2014                504          97.0324
# 12  United States  USA  2015                465          92.5329
# ...

# %% [markdown]
# The merged dataset, obtained through an inner merge of data_1 and data_2 on the 'Entity', 'Code', and 'Year' columns, provides a comprehensive overview of tuberculosis-related data for the United States across multiple years. The resulting DataFrame, named merged_data, includes additional columns such as 'tb_positive_count' and 'TB_death_counts'. Merging datasets is crucial for data enrichment, allowing for the combination of information from different sources to create a more complete and integrated dataset. In this context, the merged data facilitates analysis, enabling a more in-depth examination of the relationship between tuberculosis-positive counts and corresponding death counts over the years. This consolidated dataset is valuable for trend analysis, pattern identification, and gaining insights into how these health-related variables evolve over time for a specific entity.

# %% [markdown]
# ## **Convert the dtype**

# %%
# Convert the 'tb_positive_count' column in the 'merged_data' DataFrame to the float data type
merged_data['tb_positive_count'] = merged_data['tb_positive_count'].astype(float)

# %% [markdown]
# # **Calculation**

# %%
# Calculate and create a new column 'Ratio_TB_pos_to_death' by dividing 'tb_positive_count' by 'TB_death_counts' in 'merged_data'
merged_data['Ratio_TB_pos_to_death'] = (merged_data['tb_positive_count'] - merged_data['TB_death_counts'])

# %%
# Drop the 'Code' column from the 'merged_data' DataFrame
merged_data = merged_data.drop(columns=['Code'])
merged_data
# Out:
#            Entity  Year  tb_positive_count  TB_death_counts  \
# 0   United States  2003             1317.0         417.7620
# 1   United States  2004             1188.0         364.7660
# 2   United States  2005             1035.0         320.1740
# 3   United States  2006              960.0         285.9870
# 4   United States  2007              883.0         255.9080
# 5   United States  2008              826.0         231.4140
# 6   United States  2009              711.0         191.5700
# 7   United States  2010              627.0         170.3310
# 8   United States  2011              668.0         146.6090
# 9   United States  2012              626.0         126.3020
# 10  United States  2013              552.0         106.1010
# 11  United States  2014              504.0          97.0324
# 12  United States  2015              465.0          92.5329
# 13  United States  2016              466.0          85.9345
#
#     Ratio_TB_pos_to_death
# 0                899.2380
# ...

# %% [markdown]
# ### **Data Aggregation**

# %%
# Calculate the mean of the 'tb_positive_count' column in the 'merged_data' DataFrame
merged_data["tb_positive_count"].mean()
# Out:
# 773.4285714285714

# %%
# Aggregate statistics for 'tb_positive_count' and 'TB_death_counts' columns in the 'merged_data' DataFrame
merged_data.agg({
    "tb_positive_count": ['min', 'max', 'mean', 'median', 'std', 'count'],
    "TB_death_counts": ['min', 'max', 'mean', 'median', 'std', 'count']
})
# Out:
#         tb_positive_count  TB_death_counts
# min            465.000000         85.93450
# max           1317.000000        417.76200
# mean           773.428571        206.60170
# median         689.500000        180.95050
# std            271.008008        108.52821
# count           14.000000         14.00000

# %%
# Calculate minimum, maximum, mean, standard deviation, and count for the 'Ratio_TB_pos_to_death' column in 'merged_data'
merged_data["Ratio_TB_pos_to_death"].agg(['min','max','mean','std','count'])
# Out:
# min      372.467100
# max      899.238000
# mean     566.826871
# std      163.571398
# count     14.000000
# Name: Ratio_TB_pos_to_death, dtype: float64

# %% [markdown]
# ### **pivot**

# %%
merged_data_1_pivoted = merged_data.pivot_table(
    values=['tb_positive_count'],
    index='Year',
    columns='Entity',
    aggfunc=ny.sum,
    fill_value=0
)
merged_data_1_pivoted
# Out:
#        tb_positive_count
# Entity     United States
# Year
# 2003                1317
# 2004                1188
# 2005                1035
# 2006                 960
# 2007                 883
# 2008                 826
# 2009                 711
# 2010                 627
# 2011                 668
# 2012                 626
# 2013                 552
# 2014                 504
# 2015                 465
# 2016                 466

# %% [markdown]
# **VISUALIZATIONS**

# %% [markdown]
# **1.BOX PLOT**

# %%
# Assuming 'merged_data' is your DataFrame
plt.figure(figsize=(8, 6))
sns.boxplot(data=merged_data["Ratio_TB_pos_to_death"])
plt.title('Box Plot of Ratio of TB Count')
plt.xlabel('Ratio of TB Count')
plt.show()

# %% [markdown]
# **Interpretation**
#
# The boxplot serves as an illustrative representation elucidating the distributional characteristics inherent in the "Ratio_TB_pos_to_death" metric across distinct calendar years within the dataset. The median demarcation within the box imparts a salient depiction of the central tendency, offering insights into the median point of the dataset. Significantly, the box encapsulates the interquartile range (IQR), delineating the region where the central 50% of the data is concentrated. The expansiveness of the box is indicative of heightened variability in the "Ratio_TB_pos_to_death" values over the spectrum of years considered. Concurrently, the whiskers extending from the box articulate the span of the preponderance of data, with elongated whiskers emblematic of a broader dispersion of values. Noteworthy outliers, visualized as discrete data points beyond the whiskers, potentially signify extraordinary or extreme data points. The boxplot, as a methodological visualization, facilitates the discernment of temporal patterns, trends, and irregularities intrinsic to the "Ratio_TB_pos_to_death" distribution, affording a nuanced and comparative examination across disparate temporal epochs. In essence, it furnishes a succinct and erudite synopsis of central tendencies, variability, and conceivable outliers manifest in the dataset.

# %% [markdown]
# **LINE PLOT**

# %%
plt.figure(figsize=(10, 6))

# Plot 'tb_positive_count' and 'TB_death_counts' over the years
plt.plot(merged_data['Year'], merged_data['tb_positive_count'], label='TB Positive Count', marker='o')
plt.plot(merged_data['Year'], merged_data['TB_death_counts'], label='TB Death Counts', marker='o')


# Set labels and title
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('TB Positive Count and TB Death Counts Over the Years')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# **Interpretation**
#
# The rendered line plot serves as an instrumental visual exposition delineating the temporal dynamics inherent in 'TB Positive Count' and 'TB Death Counts' over the delineated chronological span. The demarcation denoted as 'TB Positive Count' delineates the yearly enumerations of individuals presenting positive results in tuberculosis (TB) diagnostic testing, thereby illuminating the nuanced oscillations in TB-positive cases across the designated temporal ambit. Simultaneously, the line designating 'TB Death Counts' encapsulates the annual enumerations of mortalities attributed to tuberculosis, thereby elucidating discernible variances in TB-related fatality throughout the stipulated temporal epoch. The markers affixed to the data points, denoted by 'o', contribute to the meticulous depiction of annual vicissitudes in both TB positive cases and TB-associated mortalities. Through the amalgamation of both variables within a singular plot, the visualization aptly facilitates a comparative inquiry, affording an evaluative lens for discerning potential correlative or divergent trends between the two salient health indicators. In sum, this methodical visual exposition engenders an insightful exploration into the nuanced temporal trajectories of TB cases and associated mortalities, thereby enriching the scholarly understanding of public health dynamics within the specified temporal purview.

# %% [markdown]
# **Data:3**
#
# The 'data3' dataset captures information on TB patients living with HIV and receiving Antiretroviral Therapy (ART) across various countries from 2007 to 2016. It includes columns such as 'Entity,' 'Code,' 'Year,' and 'TB patients living with HIV receiving ART - Total.' The latter represents the count of individuals with both TB and HIV receiving ART each year. Descriptive statistics for the numerical column 'TB patients living with HIV receiving ART - Total'

# %%
# Load data from a JSON file named "tb-patients-living-with-hiv-receiving-art.json" into a DataFrame named 'data3'
data3= pd.read_json("tb-patients-living-with-hiv-receiving-art.json")
data3
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2007
# 1     Afghanistan  AFG  2008
# 2     Afghanistan  AFG  2009
# 3     Afghanistan  AFG  2010
# 4     Afghanistan  AFG  2011
# ...           ...  ...   ...
# 1960     Zimbabwe  ZWE  2012
# 1961     Zimbabwe  ZWE  2013
# 1962     Zimbabwe  ZWE  2014
# 1963     Zimbabwe  ZWE  2015
# 1964     Zimbabwe  ZWE  2016
#
#       TB patients living with HIV receiving ART - Total
# 0                                                     0
# 1                                                     0
# 2                                                     5
# 3                                                     2
# 4                                                     4
# ...                                                 ...
# 1960                                              18158
# 1961                                              18575
# 1962                                              16522
# ...

# %%
# Filter rows where 'Entity' is 'India'
data3 = data3[data3['Entity'] == 'India']
data3
# Out:
#     Entity Code  Year  TB patients living with HIV receiving ART - Total
# 770  India  IND  2007                                                162
# 771  India  IND  2008                                               2487
# 772  India  IND  2009                                              18188
# 773  India  IND  2010                                              23641
# 774  India  IND  2011                                              26165
# 775  India  IND  2012                                              25790
# 776  India  IND  2013                                              39821
# 777  India  IND  2014                                              39800
# 778  India  IND  2015                                              40925
# 779  India  IND  2016                                              39123

# %%
data3['Entity'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Histogram provides information about the central tendency, with a symmetric distribution suggesting a balanced set of values around a central point. The width of the histogram indicates the spread or dispersion of the data, and peaks or modes reveal regions of higher frequency. Skewness in the histogram helps identify whether the data is skewed to the left or right. Outliers, if present, may be visually apparent as isolated bars. Beyond descriptive statistics, the histogram can offer valuable insights into data quality, identifying gaps or irregularities. It serves as a foundational step in understanding the underlying patterns, trends, and characteristics of the 'Entity' values, guiding further analysis and potentially influencing data preprocessing decisions.

# %%
# Filter rows where 'Entity' is 'India'
data1 = data1[data1['Entity'] == 'India']
data1
# Out:
#     Entity Code  Year  tb_positive_count
# 929  India  IND  2005               6411
# 930  India  IND  2006               8785
# 931  India  IND  2007               9324
# 932  India  IND  2008               6039
# 933  India  IND  2009              36483
# 934  India  IND  2010              41476
# 935  India  IND  2011              44702
# 936  India  IND  2012              44063
# 937  India  IND  2013              44027
# 938  India  IND  2014              44171
# 939  India  IND  2015              44652
# 940  India  IND  2016              39815

# %%
# Filter rows in data1 for the years 2003 to 2016
data1 = data1[(data1['Year'] >= 2003) & (data1['Year'] <= 2016)]
data1
# Out:
#     Entity Code  Year  tb_positive_count
# 929  India  IND  2005               6411
# 930  India  IND  2006               8785
# 931  India  IND  2007               9324
# 932  India  IND  2008               6039
# 933  India  IND  2009              36483
# 934  India  IND  2010              41476
# 935  India  IND  2011              44702
# 936  India  IND  2012              44063
# 937  India  IND  2013              44027
# 938  India  IND  2014              44171
# 939  India  IND  2015              44652
# 940  India  IND  2016              39815

# %% [markdown]
# # The merging of **datasets**

# %%
# Merge 'data1' and 'data3' DataFrames on 'Entity', 'Code', and 'Year' using an inner join, creating 'merged_data_2'
merged_data_2= pd.merge(data1, data3, on=['Entity', 'Code', 'Year'], how='inner')
merged_data_2
# Out:
#   Entity Code  Year  tb_positive_count  \
# 0  India  IND  2007               9324
# 1  India  IND  2008               6039
# 2  India  IND  2009              36483
# 3  India  IND  2010              41476
# 4  India  IND  2011              44702
# 5  India  IND  2012              44063
# 6  India  IND  2013              44027
# 7  India  IND  2014              44171
# 8  India  IND  2015              44652
# 9  India  IND  2016              39815
#
#    TB patients living with HIV receiving ART - Total
# 0                                                162
# 1                                               2487
# 2                                              18188
# 3                                              23641
# 4                                              26165
# 5                                              25790
# 6                                              39821
# 7                                              39800
# ...

# %% [markdown]
# The merging of datasets, specifically 'data1' and 'data3' using common key columns such as "Entity," "Code," and "Year," aims to create a unified dataset ('merged_data_2') that combines information on TB positive counts and the number of TB patients living with HIV receiving antiretroviral therapy for various countries over multiple years. This merged dataset facilitates a comprehensive analysis, enabling insights into the correlation between TB and HIV, evaluating intervention effectiveness, and understanding health trends across different countries throughout the years.

# %%
merged_data_2.drop('Code', axis=1, inplace=True)
merged_data_2
# Out:
#   Entity  Year  tb_positive_count  \
# 0  India  2007               9324
# 1  India  2008               6039
# 2  India  2009              36483
# 3  India  2010              41476
# 4  India  2011              44702
# 5  India  2012              44063
# 6  India  2013              44027
# 7  India  2014              44171
# 8  India  2015              44652
# 9  India  2016              39815
#
#    TB patients living with HIV receiving ART - Total
# 0                                                162
# 1                                               2487
# 2                                              18188
# 3                                              23641
# 4                                              26165
# 5                                              25790
# 6                                              39821
# 7                                              39800
# 8                                              40925
# ...

# %%
# Calculate the difference between 'tb_positive_count' and 'TB patients living with HIV receiving ART - Total'
merged_data_2['Not_received_ART'] = merged_data_2['tb_positive_count'] - merged_data_2['TB patients living with HIV receiving ART - Total']
merged_data_2
# Out:
#   Entity  Year  tb_positive_count  \
# 0  India  2007               9324
# 1  India  2008               6039
# 2  India  2009              36483
# 3  India  2010              41476
# 4  India  2011              44702
# 5  India  2012              44063
# 6  India  2013              44027
# 7  India  2014              44171
# 8  India  2015              44652
# 9  India  2016              39815
#
#    TB patients living with HIV receiving ART - Total  Not_received_ART
# 0                                                162              9162
# 1                                               2487              3552
# 2                                              18188             18295
# 3                                              23641             17835
# 4                                              26165             18537
# 5                                              25790             18273
# 6                                              39821              4206
# ...

# %%
# Group by 'Not_received_ART' and calculate the sum of other columns
merged_data2 = merged_data_2.groupby('Not_received_ART')
merged_data2

# %% [markdown]
# ## **Aggregation**

# %%
def calculate_not_received_art_stats(df):
    """
    Calculate aggregate statistics for the 'Not_received_ART' column in the provided DataFrame.
    """
    not_received_art_stats = {
        'min': df['Not_received_ART'].min(),
        'max': df['Not_received_ART'].max(),
        'mean': df['Not_received_ART'].mean(),
        'std': df['Not_received_ART'].std(),
        'count': df['Not_received_ART'].count()
    }

    not_received_art_stats

# %%
merged_data2["Not_received_ART"].agg(['min','max','mean','std','count'])
# Out:
#                     min    max     mean  std  count
# Not_received_ART
# 692                 692    692    692.0  NaN      1
# 3552               3552   3552   3552.0  NaN      1
# 3727               3727   3727   3727.0  NaN      1
# 4206               4206   4206   4206.0  NaN      1
# 4371               4371   4371   4371.0  NaN      1
# 9162               9162   9162   9162.0  NaN      1
# 17835             17835  17835  17835.0  NaN      1
# 18273             18273  18273  18273.0  NaN      1
# 18295             18295  18295  18295.0  NaN      1
# 18537             18537  18537  18537.0  NaN      1

# %% [markdown]
# ## **Pivot table**

# %%
# Create a pivot table to show 'Not_received_ART' values by 'Entity' and 'Year'
merged_data_2_pivoted = merged_data_2.pivot_table(
    values=['Not_received_ART'],
    index='Entity',
    columns='Year',
    aggfunc=ny.sum,
    fill_value=0
)
merged_data_2_pivoted
# Out:
#        Not_received_ART                                                      \
# Year               2007  2008   2009   2010   2011   2012  2013  2014  2015
# Entity
# India              9162  3552  18295  17835  18537  18273  4206  4371  3727
#
#
# Year   2016
# Entity
# India   692

# %%
# Create a regression plot using Seaborn's regplot
sns.regplot(x="Not_received_ART", y="Year", data=merged_data_2, scatter_kws={'alpha':0.5})
# Out:
# <Axes: xlabel='Not_received_ART', ylabel='Year'>

# %% [markdown]
# The regression line's orientation signals the correlation direction between TB patients not receiving ART and time. Steepness quantifies the strength of this relationship, while data point dispersion aids outlier identification. An 'alpha' parameter enhances scatter plot transparency, and precise axis labeling clarifies metrics. As an analytical tool, this plot reveals nuanced correlations between TB patient counts and time, enriching our understanding of dataset trends.

# %%
fig, ax = plt.subplots(figsize=(12, 6))

# Plot data
merged_data_2.plot(x='Year', y=['tb_positive_count', 'TB patients living with HIV receiving ART - Total', 'Not_received_ART'], kind='bar', ax=ax, color=['blue', 'red', 'green'])

ax.set_xlabel('Year')
ax.set_ylabel('Count')
ax.set_title('TB Data over the Years')

# Display the single bar chart
plt.show()

# %% [markdown]
# The graphical representation distinguishes between three discrete variables: 'tb_positive_count' (denoted in blue), 'TB patients living with HIV receiving ART - Total' (depicted in red), and 'Not_received_ART' (illustrated in green). The horizontal axis corresponds to the chronological progression of years, affording a temporal perspective on the specified TB-related metrics. Vertical bars, erected for each year, encapsulate the respective counts of 'tb_positive_count,' 'TB patients living with HIV receiving ART - Total,' and 'Not_received_ART.' The deliberate utilization of distinct colors serves the purpose of enhancing visual discernibility and facilitating a comparative analysis of temporal fluctuations across the three metrics. Axes labels meticulously demarcate 'Year' on the x-axis and 'Count' on the y-axis, offering a precise delineation of the plotted metrics' dimensions. The chosen title, 'TB Data over the Years,' encapsulates the overarching thematic emphasis of the visual representation. The specified figure dimensions, set at 12 by 6 inches, underscore a deliberate consideration for proportional scaling within the visual presentation. In essence, this methodical visual exposition furnishes a comprehensive and scholarly elucidation of temporal variations in pivotal TB-related metrics, thereby enabling nuanced comparative analyses of their respective trends and patterns over the delineated temporal expanse.

# %% [markdown]
# # **CONCLUSION**
#
# The analysis of Tuberculosis (TB) and Human Immunodeficiency Virus (HIV) datasets spanning the years 2007 to 2016 provides a comprehensive understanding of the co-occurrence of these two significant health challenges. By merging datasets on TB-positive counts and TB-related deaths among HIV-positive individuals, the study delves into the prevalence and mortality dynamics of TB within the context of HIV. The calculation of ratios, such as the TB count to deaths, offers nuanced insights into the severity of TB within this vulnerable population, aiding in the identification of trends and patterns.
#
# The temporal dynamics are vividly explored through various visualizations, including line plots, bar charts, and a box plot representing the TB count to deaths ratio. These visual representations contribute to a detailed examination of distributional characteristics, central tendencies, and potential outliers, enriching our understanding of the evolving trends over time. Additionally, the regression plot establishes a quantitative relationship between TB patients not receiving Antiretroviral Therapy (ART) and the progression of years, providing valuable insights into the impact of ART on TB management.
#
# A specific focus on India within the analysis reveals critical insights into the progress of ART interventions among TB patients living with HIV. By comparing TB-positive counts with the number of TB patients receiving ART, this analysis sheds light on the effectiveness of ART in managing TB in the Indian context. Overall, these findings contribute to evidence-based public health strategies, interventions, and policies aimed at addressing the complex challenges posed by the co-occurrence of TB and HIV. Continued research and surveillance in this domain are imperative for advancing our ability to improve health outcomes for populations affected by these intertwined health issues globally.
